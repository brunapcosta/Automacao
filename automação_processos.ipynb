# %%
# !pip install yfinance

# %%
# !pip install pyautogui

# %%
# !pip install pyperclip

# %%
import yfinance

# %%
ticker = input("Digite o código da ação: ")
dados = yfinance.Ticker(ticker).history("6mo")
# Out:
# Digite o código da ação: PETR4.SA

# %%
fechamento = dados.Close

# %%
fechamento.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
maxima = round(fechamento.max(),2)
minima = round(fechamento.min(),2)
atual = round(fechamento[-1],2)

# %%
print(maxima)
print(minima)
print(atual)
# Out:
# 38.52
# 20.49
# 35.64

# %%
import pyautogui
import pyperclip

# %%
destinatario = "brunapadidacosta@gmail.com"
assunto = "Análise Diária"

mensagem = f"""

Bom dia,
Segue abaixo as análises da ação {ticker} dos últimos 6 meses:

Cotação Máxima: R${round(maxima,2)}
Cotação Mínima: R${round(minima,2)}
Cotação Atual:  R${round(atual,2)}

Atenciosamente,
Bruna Padilha.

"""

# %%
print(destinatario)
print(assunto)
print(mensagem)
# Out:
# brunapadidacosta@gmail.com
# Análise Diária
#
#
# Bom dia,
# Segue abaixo as análises da ação PETR4.SA dos últimos 6 meses:
#
# Cotação Máxima: R$38.52
# Cotação Mínima: R$20.49
# Cotação Atual:  R$35.64
#
# Atenciosamente,
# Bruna Padilha.

# %%
import time

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=1199, y=973)

# %%
pyautogui.PAUSE = 3

pyautogui.hotkey("ctrl", "t")

pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

pyautogui.click(x=114, y=204)

pyperclip.copy(destinatario)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")

pyperclip.copy(assunto)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")

pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")

pyautogui.click(x=1199, y=973)

pyautogui.hotkey("ctrl", "f4")

print("E-mail enviado com sucesso!")
# Out:
# E-mail enviado com sucesso!
